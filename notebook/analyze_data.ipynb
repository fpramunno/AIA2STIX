# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
test_enc = np.load('/mnt/nas05/astrodata01/aia_2_stix/encoded_data/train/train/train_encoded_features.npy')

# %%
test_enc.shape
# Out:
# (448, 48)

# %%
test_enc.max()
# Out:
# 0.77954

# %%
import numpy as np
import os
from pathlib import Path
import argparse
from tqdm import tqdm

def find_overall_minmax(directory_path, verbose=False):
    """
    Find the overall minimum and maximum values across all .npy files in a directory.
    
    Args:
        directory_path (str): Path to directory containing .npy files
        verbose (bool): Whether to print individual file stats
    
    Returns:
        tuple: (overall_min, overall_max)
    """
    # Convert to Path object for easier handling
    dir_path = Path(directory_path)
    
    # Find all .npy files
    npy_files = list(dir_path.glob("*.npy"))
    
    if not npy_files:
        print(f"No .npy files found in {directory_path}")
        return None, None
    
    print(f"Found {len(npy_files)} .npy files")
    
    # Initialize with infinity values
    overall_min = float('inf')
    overall_max = float('-inf')
    
    # Track statistics
    total_elements = 0
    processed_files = 0
    
    # Process each file
    for npy_file in tqdm(npy_files, desc="Processing files"):
        try:
            # Load the numpy array
            data = np.load(npy_file)
            
            # Get min and max for this file
            file_min = np.min(data)
            file_max = np.max(data)
            
            # Update overall min/max
            overall_min = min(overall_min, file_min)
            overall_max = max(overall_max, file_max)
            
            # Update statistics
            total_elements += data.size
            processed_files += 1
            
            if verbose:
                print(f"{npy_file.name}: shape={data.shape}, min={file_min:.6f}, max={file_max:.6f}")
                
        except Exception as e:
            print(f"Error processing {npy_file.name}: {e}")
            continue
    
    if processed_files == 0:
        print("No files were successfully processed")
        return None, None
    
    print(f"\n{'='*50}")
    print(f"SUMMARY:")
    print(f"{'='*50}")
    print(f"Files processed: {processed_files}")
    print(f"Total elements: {total_elements:,}")
    print(f"Overall MIN: {overall_min}")
    print(f"Overall MAX: {overall_max}")
    print(f"Range: {overall_max - overall_min}")
    
    return overall_min, overall_max

# %%
min_val, max_val = find_overall_minmax("/mnt/nas05/astrodata01/aia_2_stix/encoded_data/train/train/", True)
# Out:
# Found 449 .npy files
# Processing files:   5%|▍         | 22/449 [00:00<00:01, 215.18it/s]
# train_batch_0000_sample_00.npy: shape=(48,), min=-0.251100, max=0.779540
# train_batch_0000_sample_01.npy: shape=(48,), min=-0.261423, max=0.879232
# train_batch_0000_sample_02.npy: shape=(48,), min=-0.339461, max=1.039734
# train_batch_0000_sample_03.npy: shape=(48,), min=-0.511683, max=1.403757
# train_batch_0000_sample_04.npy: shape=(48,), min=-0.259517, max=0.882379
# train_batch_0000_sample_05.npy: shape=(48,), min=-0.258884, max=0.762782
# train_batch_0000_sample_06.npy: shape=(48,), min=-0.239618, max=0.796399
# train_batch_0000_sample_07.npy: shape=(48,), min=-0.260340, max=0.821965
# train_batch_0000_sample_08.npy: shape=(48,), min=-0.487683, max=1.413281
# train_batch_0000_sample_09.npy: shape=(48,), min=-0.265606, max=0.824831
# train_batch_0000_sample_10.npy: shape=(48,), min=-0.466075, max=1.203827
# train_batch_0000_sample_11.npy: shape=(48,), min=-0.215818, max=0.647545
# train_batch_0000_sample_12.npy: shape=(48,), min=-0.318117, max=0.972495
# train_batch_0000_sample_13.npy: shape=(48,), min=-0.483275, max=1.372937
# train_batch_0000_sample_14.npy: shape=(48,), min=-0.274306, max=0.907015
# train_batch_0000_sample_15.npy: shape=(48,), min=-0.240641, max=0.814532
# train_batch_0001_sample_00.npy: shape=(48,), min=-0.496780, max=1.401758
# train_batch_0001_sample_01.npy: shape=(48,), min=-0.331166, max=1.014701
# train_batch_0001_sample_02.npy: shape=(48,), min=-0.508141, max=1.411058
# train_batch_0001_sample_03.npy: shape=(48,), min=-0.312356, max=0.990512
# train_batch_0001_sample_04.npy: shape=(48,), min=-0.249817, max=0.815390
# train_batch_0001_sample_05.npy: shape=(48,), min=-0.279941, max=0.884128
# train_batch_0001_sample_06.npy: shape=(48,), min=-0.295967, max=0.920967
# train_batch_0001_sample_07.npy: shape=(48,), min=-0.284726, max=0.917231
# train_batch_0001_sample_08.npy: shape=(48,), min=-0.261419, max=0.896755
# train_batch_0001_sample_09.npy: shape=(48,), min=-0.222605, max=0.746113
# train_batch_0001_sample_10.npy: shape=(48,), min=-0.301173, max=0.904862
# train_batch_0001_sample_11.npy: shape=(48,), min=-0.483579, max=1.381677
# train_batch_0001_sample_12.npy: shape=(48,), min=-0.220562, max=0.683328
# train_batch_0001_sample_13.npy: shape=(48,), min=-0.342003, max=1.009024
# train_batch_0001_sample_14.npy: shape=(48,), min=-0.282728, max=0.850864
# train_batch_0001_sample_15.npy: shape=(48,), min=-0.478906, max=1.333796
# train_batch_0002_sample_00.npy: shape=(48,), min=-0.248617, max=0.790231
# train_batch_0002_sample_01.npy: shape=(48,), min=-0.247026, max=0.771745
# train_batch_0002_sample_02.npy: shape=(48,), min=-0.440476, max=1.258697
# train_batch_0002_sample_03.npy: shape=(48,), min=-0.230045, max=0.765923
# train_batch_0002_sample_04.npy: shape=(48,), min=-0.235842, max=0.751951
# train_batch_0002_sample_05.npy: shape=(48,), min=-0.227801, max=0.725129
# train_batch_0002_sample_06.npy: shape=(48,), min=-0.247037, max=0.821164
# train_batch_0002_sample_07.npy: shape=(48,), min=-0.238948, max=0.775082
# train_batch_0002_sample_08.npy: shape=(48,), min=-0.450742, max=1.242793
# train_batch_0002_sample_09.npy: shape=(48,), min=-0.384590, max=1.138534
# train_batch_0002_sample_10.npy: shape=(48,), min=-0.262438, max=0.823530
# Processing files:  15%|█▍        | 66/449 [00:00<00:01, 214.44it/s]
# train_batch_0002_sample_11.npy: shape=(48,), min=-0.368720, max=1.161175
# train_batch_0002_sample_12.npy: shape=(48,), min=-0.200748, max=0.587129
# train_batch_0002_sample_13.npy: shape=(48,), min=-0.446665, max=1.254634
# train_batch_0002_sample_14.npy: shape=(48,), min=-0.427441, max=1.186287
# train_batch_0002_sample_15.npy: shape=(48,), min=-0.451443, max=1.280735
# train_batch_0003_sample_00.npy: shape=(48,), min=-0.220156, max=0.751746
# train_batch_0003_sample_01.npy: shape=(48,), min=-0.215413, max=0.699420
# train_batch_0003_sample_02.npy: shape=(48,), min=-0.251942, max=0.776054
# train_batch_0003_sample_03.npy: shape=(48,), min=-0.314033, max=1.000500
# train_batch_0003_sample_04.npy: shape=(48,), min=-0.227159, max=0.764322
# train_batch_0003_sample_05.npy: shape=(48,), min=-0.449837, max=1.322899
# train_batch_0003_sample_06.npy: shape=(48,), min=-0.214405, max=0.697416
# train_batch_0003_sample_07.npy: shape=(48,), min=-0.208752, max=0.620077
# train_batch_0003_sample_08.npy: shape=(48,), min=-0.226295, max=0.693401
# train_batch_0003_sample_09.npy: shape=(48,), min=-0.267549, max=0.830913
# train_batch_0003_sample_10.npy: shape=(48,), min=-0.470112, max=1.354938
# train_batch_0003_sample_11.npy: shape=(48,), min=-0.244591, max=0.744341
# train_batch_0003_sample_12.npy: shape=(48,), min=-0.252192, max=0.854296
# train_batch_0003_sample_13.npy: shape=(48,), min=-0.424557, max=1.223179
# train_batch_0003_sample_14.npy: shape=(48,), min=-0.449838, max=1.322919
# train_batch_0003_sample_15.npy: shape=(48,), min=-0.255528, max=0.833012
# train_batch_0004_sample_00.npy: shape=(48,), min=-0.221472, max=0.738382
# train_batch_0004_sample_01.npy: shape=(48,), min=-0.480192, max=1.292767
# train_batch_0004_sample_02.npy: shape=(48,), min=-0.399462, max=1.070878
# train_batch_0004_sample_03.npy: shape=(48,), min=-0.408289, max=1.160432
# train_batch_0004_sample_04.npy: shape=(48,), min=-0.413671, max=1.152929
# train_batch_0004_sample_05.npy: shape=(48,), min=-0.489625, max=1.322421
# train_batch_0004_sample_06.npy: shape=(48,), min=-0.317014, max=1.007739
# train_batch_0004_sample_07.npy: shape=(48,), min=-0.237072, max=0.736412
# train_batch_0004_sample_08.npy: shape=(48,), min=-0.246658, max=0.858297
# train_batch_0004_sample_09.npy: shape=(48,), min=-0.238959, max=0.784051
# train_batch_0004_sample_10.npy: shape=(48,), min=-0.236737, max=0.759487
# train_batch_0004_sample_11.npy: shape=(48,), min=-0.486408, max=1.348786
# train_batch_0004_sample_12.npy: shape=(48,), min=-0.247498, max=0.816240
# train_batch_0004_sample_13.npy: shape=(48,), min=-0.235106, max=0.780907
# train_batch_0004_sample_14.npy: shape=(48,), min=-0.232133, max=0.721166
# train_batch_0004_sample_15.npy: shape=(48,), min=-0.405270, max=1.174093
# train_batch_0005_sample_00.npy: shape=(48,), min=-0.241378, max=0.802789
# train_batch_0005_sample_01.npy: shape=(48,), min=-0.406536, max=1.072725
# train_batch_0005_sample_02.npy: shape=(48,), min=-0.254787, max=0.799663
# train_batch_0005_sample_03.npy: shape=(48,), min=-0.219194, max=0.634662
# train_batch_0005_sample_04.npy: shape=(48,), min=-0.245417, max=0.806364
# train_batch_0005_sample_05.npy: shape=(48,), min=-0.265842, max=0.862202
# train_batch_0005_sample_06.npy: shape=(48,), min=-0.371655, max=1.098450
# Processing files:  24%|██▍       | 110/449 [00:00<00:01, 214.89it/s]
# train_batch_0005_sample_07.npy: shape=(48,), min=-0.220622, max=0.703015
# train_batch_0005_sample_08.npy: shape=(48,), min=-0.424323, max=1.157467
# train_batch_0005_sample_09.npy: shape=(48,), min=-0.362908, max=1.112522
# train_batch_0005_sample_10.npy: shape=(48,), min=-0.263374, max=0.858440
# train_batch_0005_sample_11.npy: shape=(48,), min=-0.217546, max=0.669735
# train_batch_0005_sample_12.npy: shape=(48,), min=-0.461419, max=1.187514
# train_batch_0005_sample_13.npy: shape=(48,), min=-0.212600, max=0.656030
# train_batch_0005_sample_14.npy: shape=(48,), min=-0.345325, max=0.996931
# train_batch_0005_sample_15.npy: shape=(48,), min=-0.301920, max=0.907618
# train_batch_0006_sample_00.npy: shape=(48,), min=-0.334699, max=1.032868
# train_batch_0006_sample_01.npy: shape=(48,), min=-0.218652, max=0.666610
# train_batch_0006_sample_02.npy: shape=(48,), min=-0.434654, max=1.252183
# train_batch_0006_sample_03.npy: shape=(48,), min=-0.286923, max=0.907106
# train_batch_0006_sample_04.npy: shape=(48,), min=-0.413819, max=1.220709
# train_batch_0006_sample_05.npy: shape=(48,), min=-0.462884, max=1.337318
# train_batch_0006_sample_06.npy: shape=(48,), min=-0.267351, max=0.823864
# train_batch_0006_sample_07.npy: shape=(48,), min=-0.410456, max=1.171103
# train_batch_0006_sample_08.npy: shape=(48,), min=-0.465891, max=1.345034
# train_batch_0006_sample_09.npy: shape=(48,), min=-0.231220, max=0.700996
# train_batch_0006_sample_10.npy: shape=(48,), min=-0.415858, max=1.118748
# train_batch_0006_sample_11.npy: shape=(48,), min=-0.235555, max=0.807042
# train_batch_0006_sample_12.npy: shape=(48,), min=-0.261470, max=0.876855
# train_batch_0006_sample_13.npy: shape=(48,), min=-0.218905, max=0.731924
# train_batch_0006_sample_14.npy: shape=(48,), min=-0.254628, max=0.882473
# train_batch_0006_sample_15.npy: shape=(48,), min=-0.242521, max=0.794797
# train_batch_0007_sample_00.npy: shape=(48,), min=-0.238122, max=0.714267
# train_batch_0007_sample_01.npy: shape=(48,), min=-0.241866, max=0.779527
# train_batch_0007_sample_02.npy: shape=(48,), min=-0.220999, max=0.737907
# train_batch_0007_sample_03.npy: shape=(48,), min=-0.230128, max=0.735143
# train_batch_0007_sample_04.npy: shape=(48,), min=-0.245611, max=0.846899
# train_batch_0007_sample_05.npy: shape=(48,), min=-0.433461, max=1.252513
# train_batch_0007_sample_06.npy: shape=(48,), min=-0.423571, max=1.255061
# train_batch_0007_sample_07.npy: shape=(48,), min=-0.503310, max=1.409033
# train_batch_0007_sample_08.npy: shape=(48,), min=-0.464745, max=1.218293
# train_batch_0007_sample_09.npy: shape=(48,), min=-0.238509, max=0.783160
# train_batch_0007_sample_10.npy: shape=(48,), min=-0.457715, max=1.276451
# train_batch_0007_sample_11.npy: shape=(48,), min=-0.214231, max=0.654281
# train_batch_0007_sample_12.npy: shape=(48,), min=-0.249051, max=0.817274
# train_batch_0007_sample_13.npy: shape=(48,), min=-0.355461, max=1.015695
# train_batch_0007_sample_14.npy: shape=(48,), min=-0.256221, max=0.780890
# train_batch_0007_sample_15.npy: shape=(48,), min=-0.230513, max=0.785627
# train_batch_0008_sample_00.npy: shape=(48,), min=-0.244815, max=0.776418
# train_batch_0008_sample_01.npy: shape=(48,), min=-0.222743, max=0.711648
# train_batch_0008_sample_02.npy: shape=(48,), min=-0.279513, max=0.939763
# Processing files:  34%|███▍      | 154/449 [00:00<00:01, 214.80it/s]
# train_batch_0008_sample_03.npy: shape=(48,), min=-0.234697, max=0.781487
# train_batch_0008_sample_04.npy: shape=(48,), min=-0.238462, max=0.737084
# train_batch_0008_sample_05.npy: shape=(48,), min=-0.215186, max=0.668206
# train_batch_0008_sample_06.npy: shape=(48,), min=-0.280201, max=0.879038
# train_batch_0008_sample_07.npy: shape=(48,), min=-0.291485, max=0.961913
# train_batch_0008_sample_08.npy: shape=(48,), min=-0.394445, max=1.096275
# train_batch_0008_sample_09.npy: shape=(48,), min=-0.260622, max=0.819192
# train_batch_0008_sample_10.npy: shape=(48,), min=-0.407908, max=1.135808
# train_batch_0008_sample_11.npy: shape=(48,), min=-0.247318, max=0.825384
# train_batch_0008_sample_12.npy: shape=(48,), min=-0.281664, max=0.926386
# train_batch_0008_sample_13.npy: shape=(48,), min=-0.241195, max=0.802467
# train_batch_0008_sample_14.npy: shape=(48,), min=-0.234109, max=0.753715
# train_batch_0008_sample_15.npy: shape=(48,), min=-0.294910, max=0.917471
# train_batch_0009_sample_00.npy: shape=(48,), min=-0.367185, max=1.110797
# train_batch_0009_sample_01.npy: shape=(48,), min=-0.454388, max=1.168725
# train_batch_0009_sample_02.npy: shape=(48,), min=-0.420642, max=1.140245
# train_batch_0009_sample_03.npy: shape=(48,), min=-0.445567, max=1.326244
# train_batch_0009_sample_04.npy: shape=(48,), min=-0.253119, max=0.806312
# train_batch_0009_sample_05.npy: shape=(48,), min=-0.273621, max=0.888710
# train_batch_0009_sample_06.npy: shape=(48,), min=-0.461590, max=1.231286
# train_batch_0009_sample_07.npy: shape=(48,), min=-0.459435, max=1.243151
# train_batch_0009_sample_08.npy: shape=(48,), min=-0.263294, max=0.920952
# train_batch_0009_sample_09.npy: shape=(48,), min=-0.252807, max=0.871657
# train_batch_0009_sample_10.npy: shape=(48,), min=-0.244490, max=0.861761
# train_batch_0009_sample_11.npy: shape=(48,), min=-0.228477, max=0.742497
# train_batch_0009_sample_12.npy: shape=(48,), min=-0.430484, max=1.262579
# train_batch_0009_sample_13.npy: shape=(48,), min=-0.271553, max=0.894178
# train_batch_0009_sample_14.npy: shape=(48,), min=-0.240107, max=0.781584
# train_batch_0009_sample_15.npy: shape=(48,), min=-0.311628, max=0.950265
# train_batch_0010_sample_00.npy: shape=(48,), min=-0.252163, max=0.809059
# train_batch_0010_sample_01.npy: shape=(48,), min=-0.342688, max=1.017448
# train_batch_0010_sample_02.npy: shape=(48,), min=-0.412662, max=1.103248
# train_batch_0010_sample_03.npy: shape=(48,), min=-0.247002, max=0.788479
# train_batch_0010_sample_04.npy: shape=(48,), min=-0.276779, max=0.859836
# train_batch_0010_sample_05.npy: shape=(48,), min=-0.234087, max=0.738869
# train_batch_0010_sample_06.npy: shape=(48,), min=-0.518387, max=1.435020
# train_batch_0010_sample_07.npy: shape=(48,), min=-0.475960, max=1.351523
# train_batch_0010_sample_08.npy: shape=(48,), min=-0.227165, max=0.696389
# train_batch_0010_sample_09.npy: shape=(48,), min=-0.453899, max=1.233366
# train_batch_0010_sample_10.npy: shape=(48,), min=-0.249119, max=0.843425
# train_batch_0010_sample_11.npy: shape=(48,), min=-0.229900, max=0.787370
# train_batch_0010_sample_12.npy: shape=(48,), min=-0.416168, max=1.179527
# train_batch_0010_sample_13.npy: shape=(48,), min=-0.231450, max=0.760356
# train_batch_0010_sample_14.npy: shape=(48,), min=-0.318413, max=1.013219
# Processing files:  44%|████▍     | 198/449 [00:00<00:01, 214.61it/s]
# train_batch_0010_sample_15.npy: shape=(48,), min=-0.281803, max=0.919077
# train_batch_0011_sample_00.npy: shape=(48,), min=-0.421566, max=1.083161
# train_batch_0011_sample_01.npy: shape=(48,), min=-0.485714, max=1.360348
# train_batch_0011_sample_02.npy: shape=(48,), min=-0.208452, max=0.673820
# train_batch_0011_sample_03.npy: shape=(48,), min=-0.286267, max=0.923807
# train_batch_0011_sample_04.npy: shape=(48,), min=-0.403853, max=1.190456
# train_batch_0011_sample_05.npy: shape=(48,), min=-0.450393, max=1.305100
# train_batch_0011_sample_06.npy: shape=(48,), min=-0.498724, max=1.334433
# train_batch_0011_sample_07.npy: shape=(48,), min=-0.250320, max=0.836173
# train_batch_0011_sample_08.npy: shape=(48,), min=-0.416318, max=1.150844
# train_batch_0011_sample_09.npy: shape=(48,), min=-0.456907, max=1.348847
# train_batch_0011_sample_10.npy: shape=(48,), min=-0.501802, max=1.322711
# train_batch_0011_sample_11.npy: shape=(48,), min=-0.393518, max=1.141893
# train_batch_0011_sample_12.npy: shape=(48,), min=-0.503010, max=1.366429
# train_batch_0011_sample_13.npy: shape=(48,), min=-0.480122, max=1.262909
# train_batch_0011_sample_14.npy: shape=(48,), min=-0.305744, max=0.935620
# train_batch_0011_sample_15.npy: shape=(48,), min=-0.235236, max=0.778815
# train_batch_0012_sample_00.npy: shape=(48,), min=-0.470398, max=1.344152
# train_batch_0012_sample_01.npy: shape=(48,), min=-0.409553, max=1.084368
# train_batch_0012_sample_02.npy: shape=(48,), min=-0.206151, max=0.712856
# train_batch_0012_sample_03.npy: shape=(48,), min=-0.243668, max=0.795555
# train_batch_0012_sample_04.npy: shape=(48,), min=-0.242183, max=0.775718
# train_batch_0012_sample_05.npy: shape=(48,), min=-0.237509, max=0.780124
# train_batch_0012_sample_06.npy: shape=(48,), min=-0.428577, max=1.245808
# train_batch_0012_sample_07.npy: shape=(48,), min=-0.222939, max=0.727080
# train_batch_0012_sample_08.npy: shape=(48,), min=-0.305620, max=0.952646
# train_batch_0012_sample_09.npy: shape=(48,), min=-0.248136, max=0.838172
# train_batch_0012_sample_10.npy: shape=(48,), min=-0.236267, max=0.732228
# train_batch_0012_sample_11.npy: shape=(48,), min=-0.236986, max=0.784423
# train_batch_0012_sample_12.npy: shape=(48,), min=-0.477419, max=1.209656
# train_batch_0012_sample_13.npy: shape=(48,), min=-0.214077, max=0.653244
# train_batch_0012_sample_14.npy: shape=(48,), min=-0.230889, max=0.738905
# train_batch_0012_sample_15.npy: shape=(48,), min=-0.243658, max=0.799864
# train_batch_0013_sample_00.npy: shape=(48,), min=-0.296140, max=0.922975
# train_batch_0013_sample_01.npy: shape=(48,), min=-0.413578, max=1.178755
# train_batch_0013_sample_02.npy: shape=(48,), min=-0.275183, max=0.962696
# train_batch_0013_sample_03.npy: shape=(48,), min=-0.260425, max=0.863810
# train_batch_0013_sample_04.npy: shape=(48,), min=-0.420181, max=1.256739
# train_batch_0013_sample_05.npy: shape=(48,), min=-0.304133, max=0.946829
# train_batch_0013_sample_06.npy: shape=(48,), min=-0.233946, max=0.776187
# train_batch_0013_sample_07.npy: shape=(48,), min=-0.369025, max=1.060740
# train_batch_0013_sample_08.npy: shape=(48,), min=-0.247850, max=0.769437
# train_batch_0013_sample_09.npy: shape=(48,), min=-0.258219, max=0.876500
# train_batch_0013_sample_10.npy: shape=(48,), min=-0.245952, max=0.845585
# Processing files:  54%|█████▍    | 242/449 [00:01<00:00, 213.96it/s]
# train_batch_0013_sample_11.npy: shape=(48,), min=-0.239552, max=0.819337
# train_batch_0013_sample_12.npy: shape=(48,), min=-0.230049, max=0.742600
# train_batch_0013_sample_13.npy: shape=(48,), min=-0.488200, max=1.360652
# train_batch_0013_sample_14.npy: shape=(48,), min=-0.249506, max=0.855512
# train_batch_0013_sample_15.npy: shape=(48,), min=-0.433910, max=1.185837
# train_batch_0014_sample_00.npy: shape=(48,), min=-0.210760, max=0.697910
# train_batch_0014_sample_01.npy: shape=(48,), min=-0.441116, max=1.262099
# train_batch_0014_sample_02.npy: shape=(48,), min=-0.307949, max=0.917956
# train_batch_0014_sample_03.npy: shape=(48,), min=-0.238501, max=0.796047
# train_batch_0014_sample_04.npy: shape=(48,), min=-0.253324, max=0.838177
# train_batch_0014_sample_05.npy: shape=(48,), min=-0.339101, max=0.988723
# train_batch_0014_sample_06.npy: shape=(48,), min=-0.259680, max=0.864230
# train_batch_0014_sample_07.npy: shape=(48,), min=-0.412105, max=1.194468
# train_batch_0014_sample_08.npy: shape=(48,), min=-0.243557, max=0.831453
# train_batch_0014_sample_09.npy: shape=(48,), min=-0.248774, max=0.754149
# train_batch_0014_sample_10.npy: shape=(48,), min=-0.450688, max=1.260156
# train_batch_0014_sample_11.npy: shape=(48,), min=-0.225918, max=0.700480
# train_batch_0014_sample_12.npy: shape=(48,), min=-0.244422, max=0.730072
# train_batch_0014_sample_13.npy: shape=(48,), min=-0.263368, max=0.788309
# train_batch_0014_sample_14.npy: shape=(48,), min=-0.428830, max=1.157179
# train_batch_0014_sample_15.npy: shape=(48,), min=-0.216118, max=0.685637
# train_batch_0015_sample_00.npy: shape=(48,), min=-0.295596, max=0.953488
# train_batch_0015_sample_01.npy: shape=(48,), min=-0.432622, max=1.223145
# train_batch_0015_sample_02.npy: shape=(48,), min=-0.239312, max=0.768125
# train_batch_0015_sample_03.npy: shape=(48,), min=-0.250591, max=0.828465
# train_batch_0015_sample_04.npy: shape=(48,), min=-0.296030, max=0.900926
# train_batch_0015_sample_05.npy: shape=(48,), min=-0.506989, max=1.218141
# train_batch_0015_sample_06.npy: shape=(48,), min=-0.227238, max=0.762051
# train_batch_0015_sample_07.npy: shape=(48,), min=-0.235393, max=0.751229
# train_batch_0015_sample_08.npy: shape=(48,), min=-0.237985, max=0.797682
# train_batch_0015_sample_09.npy: shape=(48,), min=-0.247407, max=0.796357
# train_batch_0015_sample_10.npy: shape=(48,), min=-0.258423, max=0.832114
# train_batch_0015_sample_11.npy: shape=(48,), min=-0.316679, max=0.943997
# train_batch_0015_sample_12.npy: shape=(48,), min=-0.273533, max=0.860223
# train_batch_0015_sample_13.npy: shape=(48,), min=-0.279461, max=0.912746
# train_batch_0015_sample_14.npy: shape=(48,), min=-0.407985, max=1.140897
# train_batch_0015_sample_15.npy: shape=(48,), min=-0.500409, max=1.309163
# train_batch_0016_sample_00.npy: shape=(48,), min=-0.253259, max=0.842576
# train_batch_0016_sample_01.npy: shape=(48,), min=-0.269745, max=0.871155
# train_batch_0016_sample_02.npy: shape=(48,), min=-0.394736, max=1.149891
# train_batch_0016_sample_03.npy: shape=(48,), min=-0.223878, max=0.727128
# train_batch_0016_sample_04.npy: shape=(48,), min=-0.275819, max=0.892584
# train_batch_0016_sample_05.npy: shape=(48,), min=-0.312032, max=0.997476
# train_batch_0016_sample_06.npy: shape=(48,), min=-0.426221, max=1.269778
# Processing files:  64%|██████▎   | 286/449 [00:01<00:00, 215.53it/s]
# train_batch_0016_sample_07.npy: shape=(48,), min=-0.214276, max=0.744124
# train_batch_0016_sample_08.npy: shape=(48,), min=-0.237502, max=0.785311
# train_batch_0016_sample_09.npy: shape=(48,), min=-0.437602, max=1.226330
# train_batch_0016_sample_10.npy: shape=(48,), min=-0.399462, max=1.170761
# train_batch_0016_sample_11.npy: shape=(48,), min=-0.387837, max=1.089571
# train_batch_0016_sample_12.npy: shape=(48,), min=-0.289193, max=0.977025
# train_batch_0016_sample_13.npy: shape=(48,), min=-0.252668, max=0.780733
# train_batch_0016_sample_14.npy: shape=(48,), min=-0.202368, max=0.663472
# train_batch_0016_sample_15.npy: shape=(48,), min=-0.253578, max=0.825761
# train_batch_0017_sample_00.npy: shape=(48,), min=-0.242154, max=0.758174
# train_batch_0017_sample_01.npy: shape=(48,), min=-0.217882, max=0.681022
# train_batch_0017_sample_02.npy: shape=(48,), min=-0.224395, max=0.732396
# train_batch_0017_sample_03.npy: shape=(48,), min=-0.267035, max=0.842340
# train_batch_0017_sample_04.npy: shape=(48,), min=-0.456398, max=1.238663
# train_batch_0017_sample_05.npy: shape=(48,), min=-0.224432, max=0.695265
# train_batch_0017_sample_06.npy: shape=(48,), min=-0.248207, max=0.778260
# train_batch_0017_sample_07.npy: shape=(48,), min=-0.224165, max=0.699738
# train_batch_0017_sample_08.npy: shape=(48,), min=-0.208574, max=0.674692
# train_batch_0017_sample_09.npy: shape=(48,), min=-0.417701, max=1.203168
# train_batch_0017_sample_10.npy: shape=(48,), min=-0.243890, max=0.758277
# train_batch_0017_sample_11.npy: shape=(48,), min=-0.241027, max=0.794153
# train_batch_0017_sample_12.npy: shape=(48,), min=-0.252185, max=0.831330
# train_batch_0017_sample_13.npy: shape=(48,), min=-0.222801, max=0.735718
# train_batch_0017_sample_14.npy: shape=(48,), min=-0.227505, max=0.669205
# train_batch_0017_sample_15.npy: shape=(48,), min=-0.280119, max=0.885709
# train_batch_0018_sample_00.npy: shape=(48,), min=-0.216755, max=0.718732
# train_batch_0018_sample_01.npy: shape=(48,), min=-0.212210, max=0.681072
# train_batch_0018_sample_02.npy: shape=(48,), min=-0.238831, max=0.741603
# train_batch_0018_sample_03.npy: shape=(48,), min=-0.348992, max=1.126031
# train_batch_0018_sample_04.npy: shape=(48,), min=-0.450738, max=1.282451
# train_batch_0018_sample_05.npy: shape=(48,), min=-0.240960, max=0.731097
# train_batch_0018_sample_06.npy: shape=(48,), min=-0.269103, max=0.888003
# train_batch_0018_sample_07.npy: shape=(48,), min=-0.245527, max=0.782115
# train_batch_0018_sample_08.npy: shape=(48,), min=-0.257397, max=0.859033
# train_batch_0018_sample_09.npy: shape=(48,), min=-0.334106, max=1.037725
# train_batch_0018_sample_10.npy: shape=(48,), min=-0.247924, max=0.816260
# train_batch_0018_sample_11.npy: shape=(48,), min=-0.494736, max=1.360141
# train_batch_0018_sample_12.npy: shape=(48,), min=-0.242593, max=0.844601
# train_batch_0018_sample_13.npy: shape=(48,), min=-0.461710, max=1.176850
# train_batch_0018_sample_14.npy: shape=(48,), min=-0.281690, max=0.869836
# train_batch_0018_sample_15.npy: shape=(48,), min=-0.288446, max=0.914300
# train_batch_0019_sample_00.npy: shape=(48,), min=-0.242769, max=0.857825
# train_batch_0019_sample_01.npy: shape=(48,), min=-0.202479, max=0.646704
# train_batch_0019_sample_02.npy: shape=(48,), min=-0.455510, max=1.224403
# Processing files:  73%|███████▎  | 330/449 [00:01<00:00, 215.77it/s]
# train_batch_0019_sample_03.npy: shape=(48,), min=-0.383534, max=1.075543
# train_batch_0019_sample_04.npy: shape=(48,), min=-0.418071, max=1.165151
# train_batch_0019_sample_05.npy: shape=(48,), min=-0.217948, max=0.690449
# train_batch_0019_sample_06.npy: shape=(48,), min=-0.247214, max=0.819134
# train_batch_0019_sample_07.npy: shape=(48,), min=-0.335068, max=1.050295
# train_batch_0019_sample_08.npy: shape=(48,), min=-0.488221, max=1.362427
# train_batch_0019_sample_09.npy: shape=(48,), min=-0.227247, max=0.722931
# train_batch_0019_sample_10.npy: shape=(48,), min=-0.471828, max=1.327236
# train_batch_0019_sample_11.npy: shape=(48,), min=-0.270319, max=0.857203
# train_batch_0019_sample_12.npy: shape=(48,), min=-0.248078, max=0.837950
# train_batch_0019_sample_13.npy: shape=(48,), min=-0.212670, max=0.631418
# train_batch_0019_sample_14.npy: shape=(48,), min=-0.223594, max=0.731103
# train_batch_0019_sample_15.npy: shape=(48,), min=-0.269230, max=0.909935
# train_batch_0020_sample_00.npy: shape=(48,), min=-0.437802, max=1.289660
# train_batch_0020_sample_01.npy: shape=(48,), min=-0.428273, max=1.266393
# train_batch_0020_sample_02.npy: shape=(48,), min=-0.421030, max=1.083396
# train_batch_0020_sample_03.npy: shape=(48,), min=-0.406892, max=1.173449
# train_batch_0020_sample_04.npy: shape=(48,), min=-0.394654, max=1.138224
# train_batch_0020_sample_05.npy: shape=(48,), min=-0.363375, max=1.118635
# train_batch_0020_sample_06.npy: shape=(48,), min=-0.312565, max=0.991837
# train_batch_0020_sample_07.npy: shape=(48,), min=-0.250399, max=0.821439
# train_batch_0020_sample_08.npy: shape=(48,), min=-0.279939, max=0.884882
# train_batch_0020_sample_09.npy: shape=(48,), min=-0.243441, max=0.802186
# train_batch_0020_sample_10.npy: shape=(48,), min=-0.266217, max=0.886121
# train_batch_0020_sample_11.npy: shape=(48,), min=-0.342953, max=1.062016
# train_batch_0020_sample_12.npy: shape=(48,), min=-0.235060, max=0.796225
# train_batch_0020_sample_13.npy: shape=(48,), min=-0.250214, max=0.814475
# train_batch_0020_sample_14.npy: shape=(48,), min=-0.240051, max=0.772341
# train_batch_0020_sample_15.npy: shape=(48,), min=-0.310395, max=0.946877
# train_batch_0021_sample_00.npy: shape=(48,), min=-0.308075, max=0.955168
# train_batch_0021_sample_01.npy: shape=(48,), min=-0.261247, max=0.873084
# train_batch_0021_sample_02.npy: shape=(48,), min=-0.221723, max=0.674188
# train_batch_0021_sample_03.npy: shape=(48,), min=-0.387500, max=1.135733
# train_batch_0021_sample_04.npy: shape=(48,), min=-0.258427, max=0.875286
# train_batch_0021_sample_05.npy: shape=(48,), min=-0.230869, max=0.797605
# train_batch_0021_sample_06.npy: shape=(48,), min=-0.384809, max=1.150885
# train_batch_0021_sample_07.npy: shape=(48,), min=-0.528060, max=1.414929
# train_batch_0021_sample_08.npy: shape=(48,), min=-0.437863, max=1.160486
# train_batch_0021_sample_09.npy: shape=(48,), min=-0.247182, max=0.839581
# train_batch_0021_sample_10.npy: shape=(48,), min=-0.211094, max=0.720352
# train_batch_0021_sample_11.npy: shape=(48,), min=-0.242301, max=0.834321
# train_batch_0021_sample_12.npy: shape=(48,), min=-0.238092, max=0.822979
# train_batch_0021_sample_13.npy: shape=(48,), min=-0.306707, max=0.945328
# train_batch_0021_sample_14.npy: shape=(48,), min=-0.452301, max=1.224395
# Processing files:  83%|████████▎ | 374/449 [00:01<00:00, 216.74it/s]
# train_batch_0021_sample_15.npy: shape=(48,), min=-0.225172, max=0.706469
# train_batch_0022_sample_00.npy: shape=(48,), min=-0.448838, max=1.238029
# train_batch_0022_sample_01.npy: shape=(48,), min=-0.426254, max=1.188273
# train_batch_0022_sample_02.npy: shape=(48,), min=-0.217426, max=0.724770
# train_batch_0022_sample_03.npy: shape=(48,), min=-0.427393, max=1.232314
# train_batch_0022_sample_04.npy: shape=(48,), min=-0.222059, max=0.700652
# train_batch_0022_sample_05.npy: shape=(48,), min=-0.455439, max=1.299369
# train_batch_0022_sample_06.npy: shape=(48,), min=-0.234631, max=0.772784
# train_batch_0022_sample_07.npy: shape=(48,), min=-0.228719, max=0.668423
# train_batch_0022_sample_08.npy: shape=(48,), min=-0.288698, max=0.963791
# train_batch_0022_sample_09.npy: shape=(48,), min=-0.226659, max=0.689477
# train_batch_0022_sample_10.npy: shape=(48,), min=-0.308817, max=0.922261
# train_batch_0022_sample_11.npy: shape=(48,), min=-0.244349, max=0.810196
# train_batch_0022_sample_12.npy: shape=(48,), min=-0.227960, max=0.678592
# train_batch_0022_sample_13.npy: shape=(48,), min=-0.251744, max=0.805279
# train_batch_0022_sample_14.npy: shape=(48,), min=-0.343857, max=0.998024
# train_batch_0022_sample_15.npy: shape=(48,), min=-0.323785, max=1.013877
# train_batch_0023_sample_00.npy: shape=(48,), min=-0.532510, max=1.438825
# train_batch_0023_sample_01.npy: shape=(48,), min=-0.421134, max=1.204709
# train_batch_0023_sample_02.npy: shape=(48,), min=-0.453013, max=1.216380
# train_batch_0023_sample_03.npy: shape=(48,), min=-0.239097, max=0.772991
# train_batch_0023_sample_04.npy: shape=(48,), min=-0.437275, max=1.208382
# train_batch_0023_sample_05.npy: shape=(48,), min=-0.230869, max=0.746494
# train_batch_0023_sample_06.npy: shape=(48,), min=-0.246025, max=0.816233
# train_batch_0023_sample_07.npy: shape=(48,), min=-0.225363, max=0.639489
# train_batch_0023_sample_08.npy: shape=(48,), min=-0.218024, max=0.712893
# train_batch_0023_sample_09.npy: shape=(48,), min=-0.207769, max=0.674664
# train_batch_0023_sample_10.npy: shape=(48,), min=-0.301049, max=0.902434
# train_batch_0023_sample_11.npy: shape=(48,), min=-0.404806, max=1.170087
# train_batch_0023_sample_12.npy: shape=(48,), min=-0.462085, max=1.283965
# train_batch_0023_sample_13.npy: shape=(48,), min=-0.248988, max=0.842095
# train_batch_0023_sample_14.npy: shape=(48,), min=-0.288153, max=0.902459
# train_batch_0023_sample_15.npy: shape=(48,), min=-0.270465, max=0.894422
# train_batch_0024_sample_00.npy: shape=(48,), min=-0.223234, max=0.712703
# train_batch_0024_sample_01.npy: shape=(48,), min=-0.230087, max=0.762486
# train_batch_0024_sample_02.npy: shape=(48,), min=-0.405631, max=1.152696
# train_batch_0024_sample_03.npy: shape=(48,), min=-0.494247, max=1.294101
# train_batch_0024_sample_04.npy: shape=(48,), min=-0.407392, max=1.176649
# train_batch_0024_sample_05.npy: shape=(48,), min=-0.313373, max=0.935213
# train_batch_0024_sample_06.npy: shape=(48,), min=-0.278311, max=0.916178
# train_batch_0024_sample_07.npy: shape=(48,), min=-0.231841, max=0.746760
# train_batch_0024_sample_08.npy: shape=(48,), min=-0.282690, max=0.793219
# train_batch_0024_sample_09.npy: shape=(48,), min=-0.443710, max=1.172561
# train_batch_0024_sample_10.npy: shape=(48,), min=-0.216215, max=0.742860
# Processing files:  93%|█████████▎| 418/449 [00:01<00:00, 216.67it/s]
# train_batch_0024_sample_11.npy: shape=(48,), min=-0.209365, max=0.663231
# train_batch_0024_sample_12.npy: shape=(48,), min=-0.209427, max=0.660889
# train_batch_0024_sample_13.npy: shape=(48,), min=-0.455412, max=1.305854
# train_batch_0024_sample_14.npy: shape=(48,), min=-0.419776, max=1.213499
# train_batch_0024_sample_15.npy: shape=(48,), min=-0.251905, max=0.834373
# train_batch_0025_sample_00.npy: shape=(48,), min=-0.316449, max=1.031590
# train_batch_0025_sample_01.npy: shape=(48,), min=-0.230630, max=0.773093
# train_batch_0025_sample_02.npy: shape=(48,), min=-0.251173, max=0.817029
# train_batch_0025_sample_03.npy: shape=(48,), min=-0.443666, max=1.217369
# train_batch_0025_sample_04.npy: shape=(48,), min=-0.439270, max=1.312492
# train_batch_0025_sample_05.npy: shape=(48,), min=-0.245152, max=0.774667
# train_batch_0025_sample_06.npy: shape=(48,), min=-0.298201, max=0.912916
# train_batch_0025_sample_07.npy: shape=(48,), min=-0.431302, max=1.247050
# train_batch_0025_sample_08.npy: shape=(48,), min=-0.211948, max=0.689313
# train_batch_0025_sample_09.npy: shape=(48,), min=-0.402039, max=1.126423
# train_batch_0025_sample_10.npy: shape=(48,), min=-0.220991, max=0.677485
# train_batch_0025_sample_11.npy: shape=(48,), min=-0.414599, max=1.087908
# train_batch_0025_sample_12.npy: shape=(48,), min=-0.454728, max=1.289666
# train_batch_0025_sample_13.npy: shape=(48,), min=-0.393095, max=1.172537
# train_batch_0025_sample_14.npy: shape=(48,), min=-0.318460, max=0.963444
# train_batch_0025_sample_15.npy: shape=(48,), min=-0.271584, max=0.897934
# train_batch_0026_sample_00.npy: shape=(48,), min=-0.215055, max=0.644086
# train_batch_0026_sample_01.npy: shape=(48,), min=-0.225546, max=0.754710
# train_batch_0026_sample_02.npy: shape=(48,), min=-0.210924, max=0.664032
# train_batch_0026_sample_03.npy: shape=(48,), min=-0.336804, max=0.950629
# train_batch_0026_sample_04.npy: shape=(48,), min=-0.235569, max=0.801225
# train_batch_0026_sample_05.npy: shape=(48,), min=-0.378875, max=1.144403
# train_batch_0026_sample_06.npy: shape=(48,), min=-0.494266, max=1.372170
# train_batch_0026_sample_07.npy: shape=(48,), min=-0.211985, max=0.730314
# train_batch_0026_sample_08.npy: shape=(48,), min=-0.222760, max=0.747013
# train_batch_0026_sample_09.npy: shape=(48,), min=-0.330758, max=0.996770
# train_batch_0026_sample_10.npy: shape=(48,), min=-0.236722, max=0.754484
# train_batch_0026_sample_11.npy: shape=(48,), min=-0.256728, max=0.825616
# train_batch_0026_sample_12.npy: shape=(48,), min=-0.239885, max=0.748249
# train_batch_0026_sample_13.npy: shape=(48,), min=-0.206905, max=0.635406
# train_batch_0026_sample_14.npy: shape=(48,), min=-0.312394, max=0.990736
# train_batch_0026_sample_15.npy: shape=(48,), min=-0.227631, max=0.731752
# train_batch_0027_sample_00.npy: shape=(48,), min=-0.243158, max=0.745774
# train_batch_0027_sample_01.npy: shape=(48,), min=-0.469231, max=1.135900
# train_batch_0027_sample_02.npy: shape=(48,), min=-0.315180, max=0.976050
# train_batch_0027_sample_03.npy: shape=(48,), min=-0.242829, max=0.826842
# train_batch_0027_sample_04.npy: shape=(48,), min=-0.242962, max=0.800608
# train_batch_0027_sample_05.npy: shape=(48,), min=-0.225902, max=0.702599
# train_batch_0027_sample_06.npy: shape=(48,), min=-0.246273, max=0.809959
# Processing files: 100%|██████████| 449/449 [00:02<00:00, 215.24it/s]
# train_batch_0027_sample_07.npy: shape=(48,), min=-0.250355, max=0.813991
# train_batch_0027_sample_08.npy: shape=(48,), min=-0.432000, max=1.332256
# train_batch_0027_sample_09.npy: shape=(48,), min=-0.262167, max=0.845923
# train_batch_0027_sample_10.npy: shape=(48,), min=-0.243559, max=0.785114
# train_batch_0027_sample_11.npy: shape=(48,), min=-0.418383, max=1.239714
# train_batch_0027_sample_12.npy: shape=(48,), min=-0.246306, max=0.779246
# train_batch_0027_sample_13.npy: shape=(48,), min=-0.482136, max=1.207918
# train_batch_0027_sample_14.npy: shape=(48,), min=-0.385194, max=1.005132
# train_batch_0027_sample_15.npy: shape=(48,), min=-0.517116, max=1.444429
# train_encoded_features.npy: shape=(448, 48), min=-0.532510, max=1.444429
#
# ==================================================
# SUMMARY:
# ==================================================
# Files processed: 449
# Total elements: 43,008
# Overall MIN: -0.5325101613998413
# Overall MAX: 1.444428563117981
# Range: 1.9769387245178223
